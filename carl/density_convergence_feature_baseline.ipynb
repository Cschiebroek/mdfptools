# %%
from simtk import unit
from openmm import app

from openmm import *
from openmm.app import *
from mdtraj.reporters import HDF5Reporter
from utils import *

import os

class BaseSimulator():
    """
    .. warning :: The base class should not be used directly

    Parameters
    ------------
    temperature : simtk.unit
        default 298.15 K
    pressure : simtk.unit
        default 1.013 bar
    time_step : simtk.unit
        default 2 fs


    .. todo::
        - setter and getter for phy constants
    """

    temperature = 298.15 * unit.kelvin
    pressure = 1.013 * unit.bar
    time_step = 0.002 * unit.picoseconds
    equil_steps = 50000  #100 ps

    @classmethod
    def via_openmm(cls, parmed_obj, file_name, file_path = "./", platform = "CUDA", num_steps = 5000 * 500, write_out_freq = 5000, report_equilibration = True, report_production = False,
    constrain_all_bonds = True, **kwargs):
        """
        Runs simulation using OpenMM.

        Parameters
        ------------
        parmed_obj : parmed.structure
            Parmed object of the fully parameterised simulated system.
        file_name : str
            No file type postfix is necessary
        file_path : str
            Default to current directory
        platform : str
            The computing architecture to do the calculation, default to CUDA, CPU, OpenCL is also possible.
        num_steps : int
            Number of production simulation to run, default 2,500,000 steps, i.e. 5 ns.
        write_out_freq : int
            Write out every nth frame of simulated trajectory, default to every 5000 frame write out one, i.e. 10 ps per frame.

        Returns
        --------
        path : str
            The absolute path where the trajectory is written to.
        """
        platform = Platform.getPlatformByName(platform)
        pmd = parmed_obj
        path = '{}/{}.h5'.format(file_path, file_name)

        constrain_what_bond = app.AllBonds if constrain_all_bonds else app.HBonds
        system = pmd.createSystem(nonbondedMethod=app.PME, nonbondedCutoff=1*unit.nanometer, constraints=constrain_what_bond, rigidWater=False)


        thermostat = AndersenThermostat(cls.temperature, 1/unit.picosecond)
        system.addForce(thermostat)
        barostat = MonteCarloBarostat(cls.pressure , cls.temperature)
        system.addForce(barostat)
        integrator = VerletIntegrator(cls.time_step)

        simulation = Simulation(pmd.topology, system, integrator, platform)
        simulation.context.setPeriodicBoxVectors(*pmd.box_vectors)
        simulation.context.setPositions(pmd.positions)
        simulation.minimizeEnergy()

        #Eq
        try:
            cls.equil_steps = kwargs["equil_steps"]
        except KeyError:
            pass
        if report_equilibration:
            #print(cls.equil_steps, " steps")
            simulation.reporters.append(StateDataReporter("{}/equilibration_{}.dat".format(file_path, file_name), cls.equil_steps//5000, step=True, volume = True, temperature = True,density=True))
        simulation.step(cls.equil_steps)

        state = simulation.context.getState(getPositions = True, getVelocities = True)
        pmd.positions, pmd.velocities, pmd.box_vectors = state.getPositions(),state.getVelocities(), state.getPeriodicBoxVectors()

        #Production
        del system
        del simulation

        system = pmd.createSystem(nonbondedMethod=app.PME, nonbondedCutoff=1*unit.nanometer, constraints=constrain_what_bond)

        thermostat = AndersenThermostat(cls.temperature, 1/unit.picosecond)
        system.addForce(thermostat)

        integrator = VerletIntegrator(cls.time_step)
        simulation = Simulation(pmd.topology, system, integrator, platform)
        simulation.context.setPeriodicBoxVectors(*pmd.box_vectors)
        simulation.context.setPositions(pmd.positions)
        if report_production:
            simulation.reporters.append(StateDataReporter("{}/production_{}.dat".format(file_path, file_name), num_steps//50000, step=True, potentialEnergy = True, temperature = True))
        simulation.reporters.append(HDF5Reporter(path, write_out_freq))
        simulation.step(num_steps)

        return os.path.abspath(path)


class SolutionSimulator(BaseSimulator):
    """
    Perform solution simulation, namely one copy of solute in water box. Currently identical to BaseSimulator

    Parameters
    -----------
    equil_steps : int
        number of steps during equilibraion, default 50,000 steps, i.e. 100 ps
    """
    equil_steps = 50000  #100 ps

class LiquidSimulator(BaseSimulator):
    """
    Perform liquid simulation, namely multiple copy of the same molecule.

    Parameters
    -----------
    equil_steps : int
        number of steps during equilibraion, default 500,000 steps, i.e. 1 ns
    """
    equil_steps = 500000  #1 ns

# %%
# Load the PDB file and XML system into ParmEd
import openmm
from openmm.app.pdbfile import PDBFile
import parmed
import Parameteriser
from rdkit import Chem
from rdkit.Chem import rdDistGeom
from simtk import unit
smiles = "c1ccccc1"
print('Molobject created, parameterising...')
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.62 * unit.gram/unit.milliliter)
# SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_benzene_baseline', file_path = './',
#                              platform = "CUDA", num_steps = 50 * 500)
# Out:
# Molobject created, parameterising...
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmpy35ye1v6/tmpwjsgcd7v.pdb
# add_amber_ter
#
#
# structure /tmp/tmpy35ye1v6/tmp1djhsvy8.pdb
#   number 100
#   inside box 0. 0. 0. 41.332025 41.332025 41.332025
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmpy35ye1v6/tmpwjsgcd7v.pdb
#   Reading coordinate file: /tmp/tmpy35ye1v6/tmp1djhsvy8.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmpy35ye1v6/tmp1djhsvy8.pdb(          12  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :          100
#   Total number of atoms:         1200
#   Total number of molecules:          100
#   Number of fixed molecules:            0
#   Number of free molecules:          100
#   Number of variables:          600
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    4.9667183330646001
#   All atoms must be within these coordinates:
#    x: [   -996.88193092412325      ,    1003.1180690758767       ]
#    y: [   -996.79999999999995      ,    1003.2000000000000       ]
#    z: [   -999.89822643019068      ,    1000.1017735698093       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |********************************************************
#
#   Restraint-only function value:    1.9744974528907035E-002
#   Maximum violation of the restraints:    6.1834678484434333E-003
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |*******
#   Restraint-only function value:    1.1474364678693085E-002
#   Maximum violation of the restraints:    5.4937277403030536E-003
#
# ################################################################################
#
#   Objective function at initial point:    1497.8255002404915
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#
#
#   Function value from last GENCAN loop: f = .47314E-02
#   Best function value before: f = .14978E+04
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .47314E-02
#   Current structure written to file: /tmp/tmpy35ye1v6/tmpwjsgcd7v.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    4.7314091312787923E-003
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    4.7314091312787923E-003
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmpy35ye1v6/tmpwjsgcd7v.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .47314E-02
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .47314E-02
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:    4.90710028E-02  seconds.
#
# --------------------------------------------------------------------------------

# %%
SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_benzene_baseline', file_path = './',
                             platform = "CUDA", num_steps = 50 * 500)
# Out:
# '/localhome/cschiebroek/MDFP_VP/mdfptools/carl/test_benzene_baseline.h5'

# %%
#example with low experimental density (pentane, 0.61 g/mL)
smiles = 'CCCCC'
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.62 * unit.gram/unit.milliliter)
SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_pentane_baseline_d062', file_path = './',
                             platform = "CUDA", num_steps = 50 * 500)
# Out:
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmp139sce03/tmpwnb7cbaw.pdb
# add_amber_ter
#
#
# structure /tmp/tmp139sce03/tmpsvi2scfy.pdb
#   number 100
#   inside box 0. 0. 0. 40.252344 40.252344 40.252344
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmp139sce03/tmpwnb7cbaw.pdb
#   Reading coordinate file: /tmp/tmp139sce03/tmpsvi2scfy.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmp139sce03/tmpsvi2scfy.pdb(          17  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :          100
#   Total number of atoms:         1700
#   Total number of molecules:          100
#   Number of fixed molecules:            0
#   Number of free molecules:          100
#   Number of variables:          600
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    6.2209823179301837
#   All atoms must be within these coordinates:
#    x: [   -993.60000000000002      ,    1006.4000000000000       ]
#    y: [   -996.67995615637562      ,    1003.3200438436244       ]
#    z: [   -997.19149433686516      ,    1002.8085056631348       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |********************************************************
#
#   Restraint-only function value:    3.1662941122504252E-003
#   Maximum violation of the restraints:    3.1662941122504252E-003
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |*******
#   Restraint-only function value:    1.1338935156090179E-004
#   Maximum violation of the restraints:    1.1338935156090179E-004
#
# ################################################################################
#
#   Objective function at initial point:    3010.9926918091396
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#           |**************
#
#   Function value from last GENCAN loop: f = .38185E-02
#   Best function value before: f = .30110E+04
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .32694E-02
#   Current structure written to file: /tmp/tmp139sce03/tmpwnb7cbaw.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    3.8184550359001519E-003
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    3.2694076964312579E-003
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmp139sce03/tmpwnb7cbaw.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .44877E+00
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .32694E-02
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:    4.75750007E-02  seconds.
#
# --------------------------------------------------------------------------------
# '/localhome/cschiebroek/MDFP_VP/mdfptools/carl/test_pentane_baseline_d062.h5'

# %%
#example with low experimental density (pentane, 0.61 g/mL)
smiles = 'CCCCC'
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.95 * unit.gram/unit.milliliter)
SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_pentane_baseline_d095', file_path = './',
                             platform = "CUDA", num_steps = 50 * 500)
# Out:
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmp7hbk0tzn/tmpkvfw_mp3.pdb
# add_amber_ter
#
#
# structure /tmp/tmp7hbk0tzn/tmp29oeu8aa.pdb
#   number 100
#   inside box 0. 0. 0. 34.915147 34.915147 34.915147
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmp7hbk0tzn/tmpkvfw_mp3.pdb
#   Reading coordinate file: /tmp/tmp7hbk0tzn/tmp29oeu8aa.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmp7hbk0tzn/tmp29oeu8aa.pdb(          17  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :          100
#   Total number of atoms:         1700
#   Total number of molecules:          100
#   Number of fixed molecules:            0
#   Number of free molecules:          100
#   Number of variables:          600
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    6.2209823179301837
#   All atoms must be within these coordinates:
#    x: [   -993.60000000000002      ,    1006.4000000000000       ]
#    y: [   -996.67995615637562      ,    1003.3200438436244       ]
#    z: [   -997.19149433686516      ,    1002.8085056631348       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |********************************************************
#
#   Restraint-only function value:    8.0115683146780876E-003
#   Maximum violation of the restraints:    4.2114627794955176E-003
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |*******
#   Restraint-only function value:    0.0000000000000000
#   Maximum violation of the restraints:    0.0000000000000000
#
# ################################################################################
#
#   Objective function at initial point:    4573.8374391763127
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#           |***********************************
#
#   Function value from last GENCAN loop: f = .77401E-02
#   Best function value before: f = .45738E+04
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .42384E-02
#   Current structure written to file: /tmp/tmp7hbk0tzn/tmpkvfw_mp3.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    7.7401224763586551E-003
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    4.2384384908061221E-003
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmp7hbk0tzn/tmpkvfw_mp3.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .28857E+00
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .42384E-02
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:    7.37719983E-02  seconds.
#
# --------------------------------------------------------------------------------
# '/localhome/cschiebroek/MDFP_VP/mdfptools/carl/test_pentane_baseline_d095.h5'

# %%
#example with high experimental density 
smiles = 'C(C(Br)Br)(Br)Br'
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.62 * unit.gram/unit.milliliter)
SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_1122tetrabromoethane_baseline_d062', file_path = './',
                             platform = "CUDA", num_steps = 50 * 500)
# Out:
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmpav9iywo3/tmp9ihqmz7q.pdb
# add_amber_ter
#
#
# structure /tmp/tmpav9iywo3/tmp6lvyps3x.pdb
#   number 100
#   inside box 0. 0. 0. 67.856417 67.856417 67.856417
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmpav9iywo3/tmp9ihqmz7q.pdb
#   Reading coordinate file: /tmp/tmpav9iywo3/tmp6lvyps3x.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmpav9iywo3/tmp6lvyps3x.pdb(           8  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :          100
#   Total number of atoms:          800
#   Total number of molecules:          100
#   Number of fixed molecules:            0
#   Number of free molecules:          100
#   Number of variables:          600
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    4.5944432742172365
#   All atoms must be within these coordinates:
#    x: [   -996.79999999999995      ,    1003.2000000000000       ]
#    y: [   -997.82177688710760      ,    1002.1782231128924       ]
#    z: [   -997.75595635715877      ,    1002.2440436428412       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#
#
#   Restraint-only function value:    1.5584653273051877E-002
#   Maximum violation of the restraints:    8.9473120732555169E-003
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |
#   Restraint-only function value:    8.7307294649832388E-005
#   Maximum violation of the restraints:    8.7307294649832388E-005
#
# ################################################################################
#
#   Objective function at initial point:    151.79329417288159
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |*********************
#
#   Function value from last GENCAN loop: f = .12278E-01
#   Best function value before: f = .15179E+03
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .72106E-02
#   Current structure written to file: /tmp/tmpav9iywo3/tmp9ihqmz7q.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    1.2278067272417002E-002
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    7.2105993950681881E-003
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmpav9iywo3/tmp9ihqmz7q.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .18378E+00
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .72106E-02
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:    2.14380007E-02  seconds.
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1248848/1865316836.py in ?()
#       1 #example with high experimental density
#       2 smiles = 'C(C(Br)Br)(Br)Br'
#       3 rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.62 * unit.gram/unit.milliliter)
# ----> 4 SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_1122tetrabromoethane_baseline_d062', file_path = './',
#       5                              platform = "CUDA", num_steps = 50 * 500)
#
# /tmp/ipykernel_1248848/984940662.py in ?(cls, parmed_obj, file_name, file_path, platform, num_steps, write_out_freq, report_equilibration, report_production, constrain_all_bonds, **kwargs)
#     104         simulation.context.setPositions(pmd.positions)
#     105         if report_production:
#     106             simulation.reporters.append(StateDataReporter("{}/production_{}.dat".format(file_path, file_name), num_steps//50000, step=True, potentialEnergy = True, temperature = True))
#     107         simulation.reporters.append(HDF5Reporter(path, write_out_freq))
# --> 108         simulation.step(num_steps)
#     109
#     110         return os.path.abspath(path)
#
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/openmm/app/simulation.py in ?(self, steps)
#     139     def step(self, steps):
#     140         """Advance the simulation by integrating a specified number of time steps."""
# --> 141         self._simulate(endStep=self.currentStep+steps)
#
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/openmm/app/simulation.py in ?(self, endStep, endTime)
#     202                     nextSteps = nextReport[i][0]
#     203                     anyReport = True
#     204             stepsToGo = nextSteps
#     205             while stepsToGo > 10:
# --> 206                 self.integrator.step(10) # Only take 10 steps at a time, to give Python more chances to respond to a control-c.
#     207                 stepsToGo -= 10
#     208                 if endTime is not None and datetime.now() >= endTime:
#     209                     return
#
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/openmm/openmm.py in ?(self, steps)
#   10064         ----------
#   10065         steps : int
#   10066             the number of time steps to take
#   10067         """
# > 10068         return _openmm.VerletIntegrator_step(self, steps)
#
# KeyboardInterrupt:

# %%
#example with high experimental density 
smiles = 'C(C(Br)Br)(Br)Br'
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.95 * unit.gram/unit.milliliter)
SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_1122tetrabromoethane_baseline_d095', file_path = './',
                             platform = "CUDA", num_steps = 50 * 500)
# Out:
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmp0btqz3fh/tmpnk2wotmd.pdb
# add_amber_ter
#
#
# structure /tmp/tmp0btqz3fh/tmp64krhme6.pdb
#   number 100
#   inside box 0. 0. 0. 58.859100 58.859100 58.859100
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmp0btqz3fh/tmpnk2wotmd.pdb
#   Reading coordinate file: /tmp/tmp0btqz3fh/tmp64krhme6.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmp0btqz3fh/tmp64krhme6.pdb(           8  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :          100
#   Total number of atoms:          800
#   Total number of molecules:          100
#   Number of fixed molecules:            0
#   Number of free molecules:          100
#   Number of variables:          600
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    4.5944432742172365
#   All atoms must be within these coordinates:
#    x: [   -996.79999999999995      ,    1003.2000000000000       ]
#    y: [   -997.82177688710760      ,    1002.1782231128924       ]
#    z: [   -997.75595635715877      ,    1002.2440436428412       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#
#
#   Restraint-only function value:    2.2975212945433230E-007
#   Maximum violation of the restraints:    2.2975212945433230E-007
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |
#   Restraint-only function value:    0.0000000000000000
#   Maximum violation of the restraints:    0.0000000000000000
#
# ################################################################################
#
#   Objective function at initial point:    246.85965514038509
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************
#
#   Function value from last GENCAN loop: f = .41179E-03
#   Best function value before: f = .24686E+03
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .41179E-03
#   Current structure written to file: /tmp/tmp0btqz3fh/tmpnk2wotmd.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    4.1179375126151283E-004
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    4.1179375126151283E-004
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmp0btqz3fh/tmpnk2wotmd.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .92494E-01
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .41179E-03
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:    2.82359980E-02  seconds.
#
# --------------------------------------------------------------------------------
# '/localhome/cschiebroek/MDFP_VP/mdfptools/carl/test_1122tetrabromoethane_baseline_d095.h5'

# %%
# #example with huge molecule
# mol = Chem.AddHs(Chem.MolFromSmiles('CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC'))
# rdDistGeom.EmbedMolecule(mol)
# print('Molobject created, parameterising...')
# rdk_pmd = Parameteriser.SolutionParameteriser.via_rdkit(mol = mol)
# SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_long_mol_baseline', file_path = './',
#                              platform = "CUDA", num_steps = 50 * 500)
# Out:
# Molobject created, parameterising...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 5
#       3 rdDistGeom.EmbedMolecule(mol)
#       4 print('Molobject created, parameterising...')
# ----> 5 rdk_pmd = Parameteriser.SolutionParameteriser.via_rdkit(mol = mol)
#       6 SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_long_mol_baseline', file_path = './',
#       7                              platform = "CUDA", num_steps = 50 * 500)
#
# File /localhome/cschiebroek/MDFP_VP/mdfptools/carl/Parameteriser.py:233, in SolutionParameteriser.run(cls, smiles, mol, seed, solvent_smiles, allow_undefined_stereo, num_solvent, density, default_padding, box_scaleup_factor, **kwargs)
#     230 cls.smiles = smiles
#     232 # mol = cls._rdkit_charger(mol)
# --> 233 cls.pdb_filename, cls.ligand_pmd = cls._rdkit_parameteriser(mol, **kwargs)
#     234 if solvent_smiles:
#     235     mol = cls._rdkit_setter(solvent_smiles,seed, **kwargs)
#
# File /localhome/cschiebroek/MDFP_VP/mdfptools/carl/Parameteriser.py:108, in BaseParameteriser._rdkit_parameteriser(cls, mol, **kwargs)
#     106     molecule = Molecule.from_rdkit(mol, allow_undefined_stereo=cls.allow_undefined_stereo)
#     107     from openff.toolkit.utils import AmberToolsToolkitWrapper
# --> 108     molecule.assign_partial_charges(toolkit_registry=AmberToolsToolkitWrapper(),partial_charge_method="am1bcc")
#     110 except Exception as e:
#     111     raise ValueError("Charging Failed : {}".format(e))  # TODO
#
# File /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/openff/toolkit/topology/molecule.py:2610, in FrozenMolecule.assign_partial_charges(self, partial_charge_method, strict_n_conformers, use_conformers, toolkit_registry, normalize_partial_charges)
#    2608 elif isinstance(toolkit_registry, ToolkitWrapper):
#    2609     toolkit_wrapper: ToolkitWrapper = toolkit_registry
# -> 2610     toolkit_wrapper.assign_partial_charges(  # type: ignore[attr-defined]
#    2611         self,
#    2612         partial_charge_method=partial_charge_method,
#    2613         use_conformers=use_conformers,
#    2614         strict_n_conformers=strict_n_conformers,
#    2615         normalize_partial_charges=normalize_partial_charges,
#    2616         _cls=self.__class__,
#    2617     )
#    2618 else:
#    2619     raise InvalidToolkitRegistryError(
#    2620         f"Invalid toolkit_registry passed to assign_partial_charges."
#    2621         f"Expected ToolkitRegistry or ToolkitWrapper. Got  {type(toolkit_registry)}"
#    2622     )
#
# File /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/openff/toolkit/utils/ambertools_wrapper.py:215, in AmberToolsToolkitWrapper.assign_partial_charges(self, molecule, partial_charge_method, use_conformers, strict_n_conformers, normalize_partial_charges, _cls)
#     212 # Compute desired charges
#     213 # TODO: Add error handling if antechamber chokes
#     214 short_charge_method = charge_method["antechamber_keyword"]
# --> 215 subprocess.check_output(
#     216     [
#     217         "antechamber",
#     218         "-i",
#     219         "molecule.sdf",
#     220         "-fi",
#     221         "sdf",
#     222         "-o",
#     223         "charged.mol2",
#     224         "-fo",
#     225         "mol2",
#     226         "-pf",
#     227         "yes",
#     228         "-dr",
#     229         "n",
#     230         "-c",
#     231         str(short_charge_method),
#     232         "-nc",
#     233         str(net_charge),
#     234     ],
#     235     cwd=tmpdir,
#     236 )
#     237 # Write out just charges
#     238 subprocess.check_output(
#     239     [
#     240         "antechamber",
#    (...)
#     258     cwd=tmpdir,
#     259 )
#
# File /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/subprocess.py:1196, in Popen.communicate(self, input, timeout)
#    1194     self._stdin_write(input)
#    1195 elif self.stdout:
# -> 1196     stdout = self.stdout.read()
#    1197     self.stdout.close()
#    1198 elif self.stderr:
#
# KeyboardInterrupt:

# %%
#example with chloroform
smiles = 'ClC(Cl)Cl'
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.62 * unit.gram/unit.milliliter)
SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_chloroform_baseline_d062', file_path = './',
                             platform = "CUDA", num_steps = 50 * 500)
# Out:
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmpx90wc_3i/tmpkdvmwyq_.pdb
# add_amber_ter
#
#
# structure /tmp/tmpx90wc_3i/tmpayawsw25.pdb
#   number 100
#   inside box 0. 0. 0. 47.608573 47.608573 47.608573
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmpx90wc_3i/tmpkdvmwyq_.pdb
#   Reading coordinate file: /tmp/tmpx90wc_3i/tmpayawsw25.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmpx90wc_3i/tmpayawsw25.pdb(           5  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :          100
#   Total number of atoms:          500
#   Total number of molecules:          100
#   Number of fixed molecules:            0
#   Number of free molecules:          100
#   Number of variables:          600
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    2.9036991924095719
#   All atoms must be within these coordinates:
#    x: [   -998.39999999999998      ,    1001.6000000000000       ]
#    y: [   -998.53176470588232      ,    1001.4682352941177       ]
#    z: [   -998.68045157456925      ,    1001.3195484254308       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |*************************************************
#
#   Restraint-only function value:    8.9047952716296286E-003
#   Maximum violation of the restraints:    6.6935628861501499E-003
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |
#   Restraint-only function value:    0.0000000000000000
#   Maximum violation of the restraints:    0.0000000000000000
#
# ################################################################################
#
#   Objective function at initial point:    182.22981779997525
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |**************
#
#   Function value from last GENCAN loop: f = .00000E+00
#   Best function value before: f = .18223E+03
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .00000E+00
#   Current structure written to file: /tmp/tmpx90wc_3i/tmpkdvmwyq_.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    0.0000000000000000
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    0.0000000000000000
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmpx90wc_3i/tmpkdvmwyq_.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .00000E+00
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .00000E+00
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:    1.35220001E-02  seconds.
#
# --------------------------------------------------------------------------------
# '/localhome/cschiebroek/MDFP_VP/mdfptools/carl/test_chloroform_baseline_d062.h5'

# %%
smiles = 'ClC(Cl)Cl'
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.62 * unit.gram/unit.milliliter)
#save as pdb
rdk_pmd.save('chloroform_top.pdb')
# Out:
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmpsnvzbg9v/tmp32t1ksry.pdb
# add_amber_ter
#
#
# structure /tmp/tmpsnvzbg9v/tmpq6jhamyp.pdb
#   number 100
#   inside box 0. 0. 0. 47.608573 47.608573 47.608573
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmpsnvzbg9v/tmp32t1ksry.pdb
#   Reading coordinate file: /tmp/tmpsnvzbg9v/tmpq6jhamyp.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmpsnvzbg9v/tmpq6jhamyp.pdb(           5  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :          100
#   Total number of atoms:          500
#   Total number of molecules:          100
#   Number of fixed molecules:            0
#   Number of free molecules:          100
#   Number of variables:          600
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    2.9036991924095719
#   All atoms must be within these coordinates:
#    x: [   -998.39999999999998      ,    1001.6000000000000       ]
#    y: [   -998.53176470588232      ,    1001.4682352941177       ]
#    z: [   -998.68045157456925      ,    1001.3195484254308       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |*************************************************
#
#   Restraint-only function value:    8.9047952716296286E-003
#   Maximum violation of the restraints:    6.6935628861501499E-003
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |
#   Restraint-only function value:    0.0000000000000000
#   Maximum violation of the restraints:    0.0000000000000000
#
# ################################################################################
#
#   Objective function at initial point:    182.22981779997525
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |**************
#
#   Function value from last GENCAN loop: f = .00000E+00
#   Best function value before: f = .18223E+03
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .00000E+00
#   Current structure written to file: /tmp/tmpsnvzbg9v/tmp32t1ksry.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    0.0000000000000000
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    0.0000000000000000
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmpsnvzbg9v/tmp32t1ksry.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .00000E+00
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .00000E+00
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:    9.35699977E-03  seconds.
#
# --------------------------------------------------------------------------------
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################

# %%
#example with chloroform
smiles = 'ClC(Cl)Cl'
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.95 * unit.gram/unit.milliliter)
SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_chloroform_baseline_d095', file_path = './',
                             platform = "CUDA", num_steps = 50 * 500)
# Out:
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmp0agcpb__/tmpvhcij_nw.pdb
# add_amber_ter
#
#
# structure /tmp/tmp0agcpb__/tmpz59t_lnh.pdb
#   number 100
#   inside box 0. 0. 0. 41.295988 41.295988 41.295988
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmp0agcpb__/tmpvhcij_nw.pdb
#   Reading coordinate file: /tmp/tmp0agcpb__/tmpz59t_lnh.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmp0agcpb__/tmpz59t_lnh.pdb(           5  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :          100
#   Total number of atoms:          500
#   Total number of molecules:          100
#   Number of fixed molecules:            0
#   Number of free molecules:          100
#   Number of variables:          600
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    2.9036991924095719
#   All atoms must be within these coordinates:
#    x: [   -998.39999999999998      ,    1001.6000000000000       ]
#    y: [   -998.53176470588232      ,    1001.4682352941177       ]
#    z: [   -998.68045157456925      ,    1001.3195484254308       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |********************************************************
#
#   Restraint-only function value:    6.1539091108888928E-004
#   Maximum violation of the restraints:    6.1301818594387879E-004
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |
#   Restraint-only function value:    0.0000000000000000
#   Maximum violation of the restraints:    0.0000000000000000
#
# ################################################################################
#
#   Objective function at initial point:    255.49144506673630
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |****************************
#
#   Function value from last GENCAN loop: f = .59414E-02
#   Best function value before: f = .25549E+03
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .59414E-02
#   Current structure written to file: /tmp/tmp0agcpb__/tmpvhcij_nw.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    5.9414022138692063E-003
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    5.9414022138692063E-003
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmp0agcpb__/tmpvhcij_nw.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .59414E-02
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .59414E-02
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:    9.43099987E-03  seconds.
#
# --------------------------------------------------------------------------------
# '/localhome/cschiebroek/MDFP_VP/mdfptools/carl/test_chloroform_baseline_d095.h5'

# %%
#example with benzene
smiles = 'c1ccccc1'
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.95 * unit.gram/unit.milliliter)
SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_benzene_baseline_d095', file_path = './',
                             platform = "CUDA", num_steps = 1 * 1)
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.62 * unit.gram/unit.milliliter)
SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_benzene_baseline_d062', file_path = './',
                             platform = "CUDA", num_steps = 1 * 1)
# Out:
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmpno3h3pv0/tmpevt7pq8j.pdb
# add_amber_ter
#
#
# structure /tmp/tmpno3h3pv0/tmpfqb1us_r.pdb
#   number 100
#   inside box 0. 0. 0. 35.851669 35.851669 35.851669
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmpno3h3pv0/tmpevt7pq8j.pdb
#   Reading coordinate file: /tmp/tmpno3h3pv0/tmpfqb1us_r.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmpno3h3pv0/tmpfqb1us_r.pdb(          12  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :          100
#   Total number of atoms:         1200
#   Total number of molecules:          100
#   Number of fixed molecules:            0
#   Number of free molecules:          100
#   Number of variables:          600
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    4.9667183330646001
#   All atoms must be within these coordinates:
#    x: [   -996.88193092412325      ,    1003.1180690758767       ]
#    y: [   -996.79999999999995      ,    1003.2000000000000       ]
#    z: [   -999.89822643019068      ,    1000.1017735698093       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |********************************************************
#
#   Restraint-only function value:    1.7619246963366343E-002
#   Maximum violation of the restraints:    4.7355076430911306E-003
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |*******
#   Restraint-only function value:    0.0000000000000000
#   Maximum violation of the restraints:    0.0000000000000000
#
# ################################################################################
#
#   Objective function at initial point:    2511.8062412709824
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |********************************************************
#
#   Function value from last GENCAN loop: f = .00000E+00
#   Best function value before: f = .25118E+04
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .00000E+00
#   Current structure written to file: /tmp/tmpno3h3pv0/tmpevt7pq8j.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    0.0000000000000000
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    0.0000000000000000
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmpno3h3pv0/tmpevt7pq8j.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .75564E+00
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .00000E+00
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:    2.96680015E-02  seconds.
#
# --------------------------------------------------------------------------------
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmpmza7lbb_/tmpx5ylbbps.pdb
# add_amber_ter
#
#
# structure /tmp/tmpmza7lbb_/tmpz_yy23oa.pdb
#   number 100
#   inside box 0. 0. 0. 41.332025 41.332025 41.332025
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmpmza7lbb_/tmpx5ylbbps.pdb
#   Reading coordinate file: /tmp/tmpmza7lbb_/tmpz_yy23oa.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmpmza7lbb_/tmpz_yy23oa.pdb(          12  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :          100
#   Total number of atoms:         1200
#   Total number of molecules:          100
#   Number of fixed molecules:            0
#   Number of free molecules:          100
#   Number of variables:          600
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    4.9667183330646001
#   All atoms must be within these coordinates:
#    x: [   -996.88193092412325      ,    1003.1180690758767       ]
#    y: [   -996.79999999999995      ,    1003.2000000000000       ]
#    z: [   -999.89822643019068      ,    1000.1017735698093       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |********************************************************
#
#   Restraint-only function value:    1.9744974528907035E-002
#   Maximum violation of the restraints:    6.1834678484434333E-003
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |*******
#   Restraint-only function value:    1.1474364678693085E-002
#   Maximum violation of the restraints:    5.4937277403030536E-003
#
# ################################################################################
#
#   Objective function at initial point:    1497.8255002404915
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#
#
#   Function value from last GENCAN loop: f = .47314E-02
#   Best function value before: f = .14978E+04
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .47314E-02
#   Current structure written to file: /tmp/tmpmza7lbb_/tmpx5ylbbps.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    4.7314091312787923E-003
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    4.7314091312787923E-003
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmpmza7lbb_/tmpx5ylbbps.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .47314E-02
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .47314E-02
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:    2.80239992E-02  seconds.
#
# --------------------------------------------------------------------------------
# '/localhome/cschiebroek/MDFP_VP/mdfptools/carl/test_benzene_baseline_d062.h5'

# %%
#example with benzene
smiles = 'c1ccccc1'
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.62 * unit.gram/unit.milliliter)
#save topology as pdb
rdk_pmd.save('benzene_top.pdb')
# Out:
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmpf6w0ih2y/tmph9kc1zio.pdb
# add_amber_ter
#
#
# structure /tmp/tmpf6w0ih2y/tmpz9klz_m0.pdb
#   number 100
#   inside box 0. 0. 0. 41.332025 41.332025 41.332025
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmpf6w0ih2y/tmph9kc1zio.pdb
#   Reading coordinate file: /tmp/tmpf6w0ih2y/tmpz9klz_m0.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmpf6w0ih2y/tmpz9klz_m0.pdb(          12  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :          100
#   Total number of atoms:         1200
#   Total number of molecules:          100
#   Number of fixed molecules:            0
#   Number of free molecules:          100
#   Number of variables:          600
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    4.9667183330646001
#   All atoms must be within these coordinates:
#    x: [   -996.88193092412325      ,    1003.1180690758767       ]
#    y: [   -996.79999999999995      ,    1003.2000000000000       ]
#    z: [   -999.89822643019068      ,    1000.1017735698093       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |********************************************************
#
#   Restraint-only function value:    1.9744974528907035E-002
#   Maximum violation of the restraints:    6.1834678484434333E-003
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |*******
#   Restraint-only function value:    1.1474364678693085E-002
#   Maximum violation of the restraints:    5.4937277403030536E-003
#
# ################################################################################
#
#   Objective function at initial point:    1497.8255002404915
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#
#
#   Function value from last GENCAN loop: f = .47314E-02
#   Best function value before: f = .14978E+04
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .47314E-02
#   Current structure written to file: /tmp/tmpf6w0ih2y/tmph9kc1zio.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    4.7314091312787923E-003
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    4.7314091312787923E-003
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmpf6w0ih2y/tmph9kc1zio.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .47314E-02
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .47314E-02
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:    2.64279991E-02  seconds.
#
# --------------------------------------------------------------------------------
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_multiple_steps_vs_density(file_paths, labels,experimental_density = None,name=None):
    plt.figure(figsize=(10, 6))
    
    # Iterate through each file path and corresponding label
    for file_path, label in zip(file_paths, labels):
        # Read the .dat file into a DataFrame
        try:
            df = pd.read_csv(file_path)
        except FileNotFoundError:
            print(f"File not found: {file_path}")
            continue
        
        # Plot Step against Density with a unique color and label
        plt.plot(df['#"Step"'], df['Density (g/mL)'], marker='o', linestyle='-', label=label,s=4
    
    # Add labels, title, grid, and legend
    if experimental_density:
        plt.axhline(y=experimental_density, color='r', linestyle='--', label='Experimental Density')
    plt.xlabel('Step')
    plt.ylabel('Density (g/mL)')
    if name:
        plt.title(f'Density equilibration {name}')
    plt.grid(True)
    plt.legend()
    plt.show()

# Example usage with a list of file paths and corresponding labels
path_prefix = '/localhome/cschiebroek/MDFP_VP/mdfptools/carl/equilibration_test_'
name = "1122tetrabromoethane"
file_paths = [f'{path_prefix}{name}_baseline_d062.dat', f'{path_prefix}{name}_baseline_d095.dat', f'{path_prefix}{name}_full_equil.dat_0']
labels = ['v1 0.62 g/mL', 'v1 0.95 g/mL', 'v2']
plot_multiple_steps_vs_density(file_paths, labels, 2.9632,name=name)

# %%
path_prefix = '/localhome/cschiebroek/MDFP_VP/mdfptools/carl/equilibration_test_'
name = "1122tetrabromoethane"
file_path = f'{path_prefix}{name}_full_equil.dat_0'
df = pd.read_csv(file_path)
plt.plot(df['#"Step"'], df['Density (g/mL)'], marker='o', linestyle='-', label=name)
#get color of this line
color = plt.gca().lines[-1].get_color()
file_path = f'{path_prefix}{name}_full_equil.dat_1'
df = pd.read_csv(file_path)
plt.plot(df['#"Step"'], df['Density (g/mL)'], marker='o', linestyle='-', label=name, color=color)

# %%
for name,densities in zip(['1122tetrabromoethane','pentane','chloroform','benzene'],[2.9632,0.62,1.49,0.876]):
    file_paths = [f'{path_prefix}{name}_baseline_d062.dat', f'{path_prefix}{name}_baseline_d095.dat', f'{path_prefix}{name}_full_equil.dat_0']
    labels = ['v1 0.62 g/mL', 'v1 0.95 g/mL', 'v2']
    plot_multiple_steps_vs_density(file_paths, labels, name=name,experimental_density=densities)

# %%
name = 'benzene'
densities = 0.876
file_paths = [f'{path_prefix}{name}_baseline_d062.dat', f'{path_prefix}{name}_full_equil.dat_0']
labels = ['v1','v2']
plot_multiple_steps_vs_density(file_paths, labels, name=name,experimental_density=densities)

# %%
smiles = 'c1ccccc1'
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.62 * unit.gram/unit.milliliter,num_lig=1000)
SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_benzene_baseline_d062_1000', file_path = './',
                             platform = "CUDA", num_steps = 1 * 1)
name = "benzene"
file_paths = [f'{path_prefix}{name}_baseline_d062.dat', f'{path_prefix}{name}_baseline_d095.dat', f'{path_prefix}{name}_full_equil.dat_0',f'{path_prefix}{name}_baseline_d062_1000.dat']
labels = ['v1 0.62 g/mL', 'v1 0.95 g/mL', 'v2','v1 0.62 g/mL 1000 ligands']
plot_multiple_steps_vs_density(file_paths, labels,0.876,name=name)
# Out:
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
#
# ##############################################################
# The code at packmol.py:275 requires the openeye.oechem package
# ##############################################################
# # Mixture
#
# tolerance 2.000000
# filetype pdb
# output /tmp/tmp3_gm6gz9/tmp_2v227cf.pdb
# add_amber_ter
#
#
# structure /tmp/tmp3_gm6gz9/tmp4vad_ti_.pdb
#   number 1000
#   inside box 0. 0. 0. 89.047149 89.047149 89.047149
# end structure
#
#
# ################################################################################
#
#  PACKMOL - Packing optimization for the automated generation of
#  starting configurations for molecular dynamics simulations.
#
#                                                               Version 20.010
#
# ################################################################################
#
#   Packmol must be run with: packmol < inputfile.inp
#
#   Userguide at: http://m3g.iqm.unicamp.br/packmol
#
#   Reading input file... (Control-C aborts)
#   Will add the TER flag between molecules.
#   Seed for random number generator:      1234567
#   Output file: /tmp/tmp3_gm6gz9/tmp_2v227cf.pdb
#   Reading coordinate file: /tmp/tmp3_gm6gz9/tmp4vad_ti_.pdb
#   Number of independent structures:            1
#   The structures are:
#   Structure            1 :/tmp/tmp3_gm6gz9/tmp4vad_ti_.pdb(          12  atoms)
#   Maximum number of GENCAN loops for all molecule packing:          200
#   Total number of restrictions:            1
#   Distance tolerance:    2.0000000000000000
#   Warning: Type of residue numbering not set for structure            1
#   Residue numbering set for structure            1 :           0
#   Swap chains of molecules of structure            1 : F
#   Number of molecules of type            1 :         1000
#   Total number of atoms:        12000
#   Total number of molecules:         1000
#   Number of fixed molecules:            0
#   Number of free molecules:         1000
#   Number of variables:         6000
#   Total number of fixed atoms:            0
#   Maximum internal distance of type            1 :    4.9667183330646001
#   All atoms must be within these coordinates:
#    x: [   -996.88193092412325      ,    1003.1180690758767       ]
#    y: [   -996.79999999999995      ,    1003.2000000000000       ]
#    z: [   -999.89822643019068      ,    1000.1017735698093       ]
#   If the system is larger than this, increase the sidemax parameter.
#
# ################################################################################
#
#   Building initial approximation ...
#
# ################################################################################
#
#   Adjusting initial point to fit the constraints
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#           |
#
#   Restraint-only function value:    4.4701797031658193E-003
#   Maximum violation of the restraints:    1.4878731194139755E-003
#
# --------------------------------------------------------------------------------
#
#   Rescaling maximum and minimum coordinates...
#   Computing size of patches...
#   Add fixed molecules to permanent arrays...
#   Reseting center of mass...
#
# --------------------------------------------------------------------------------
#
#   Setting initial trial coordinates ...
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
#
#   Molecules of type:            1
#   Adjusting random positions to fit the constraints.
#   Packing:|0                                                             100%|
#           |****************************
#   Restraint-only function value:    4.8485118859136079E-003
#   Maximum violation of the restraints:    4.4586021482592797E-003
#
# ################################################################################
#
#   Objective function at initial point:    13362.736072976775
#
# ################################################################################
#
#   Packing molecules of type:            1
#
# ################################################################################
#
#
# --------------------------------------------------------------------------------
#
#   Starting GENCAN loop:            0
#   Scaling radii by:    1.1000000000000001
#
#   Packing:|0                                                             100%|
#           |******************************************************************|
#           |*************************************************
#
#   Function value from last GENCAN loop: f = .88167E-02
#   Best function value before: f = .13363E+05
#   Improvement from best function value:    99.99 %
#   Improvement from last loop:    99.99 %
#   Maximum violation of target distance:     0.000000
#   Maximum violation of the constraints: .69899E-02
#   Current structure written to file: /tmp/tmp3_gm6gz9/tmp_2v227cf.pdb
# --------------------------------------------------------------------------------
#   Packing solved for molecules of type           1
#   Objective function value:    8.8166697378397295E-003
#   Maximum violation of target distance:    0.0000000000000000
#   Max. constraint violation:    6.9898758242238363E-003
# --------------------------------------------------------------------------------
#
# ################################################################################
#
#   Packing all molecules together
#
# ################################################################################
#
#
#   Initial approximation is a solution. Nothing to do.
#
#   Solution written to file: /tmp/tmp3_gm6gz9/tmp_2v227cf.pdb
#
# ################################################################################
#
#                                  Success!
#               Final objective function value: .15501E-01
#               Maximum violation of target distance:   0.000000
#               Maximum violation of the constraints: .69899E-02
#
# --------------------------------------------------------------------------------
#
#               Please cite this work if Packmol was useful:
#
#            L. Martinez, R. Andrade, E. G. Birgin, J. M. Martinez,
#          PACKMOL: A package for building initial configurations for
#                    molecular dynamics simulations.
#           Journal of Computational Chemistry, 30:2157-2164,2009.
#
# ################################################################################
#
#    Running time:   0.488208979      seconds.
#
# --------------------------------------------------------------------------------

# %%
def plot_multiple_steps_vs_density(file_paths, labels,experimental_density = None,name=None):
    plt.figure(figsize=(10, 6))
    
    # Iterate through each file path and corresponding label
    for file_path, label in zip(file_paths, labels):
        # Read the .dat file into a DataFrame
        try:
            df = pd.read_csv(file_path)
        except FileNotFoundError:
            print(f"File not found: {file_path}")
            continue
        
        # Plot Step against Density with a unique color and label
        plt.plot(df['#"Step"'], df['Density (g/mL)'], marker='o', linestyle='-', label=label,markersize=2)
    
    # Add labels, title, grid, and legend
    if experimental_density:
        plt.axhline(y=experimental_density, color='r', linestyle='--', label='Experimental Density')
    plt.xlabel('Step')
    plt.ylabel('Density (g/mL)')
    if name:
        plt.title(f'Density equilibration {name}')
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
file_paths = [f'{path_prefix}{name}_baseline_d062.dat', f'{path_prefix}{name}_baseline_d095.dat', f'{path_prefix}{name}_full_equil.dat_0',f'{path_prefix}{name}_baseline_d062_1000.dat',f'{path_prefix}{name}_full_equil_n100.dat_0']
labels = ['v1 0.62 g/mL', 'v1 0.95 g/mL', 'v2','v1 0.62 g/mL 1000 ligands','v2 100 ligands']
plot_multiple_steps_vs_density(file_paths, labels,0.876,name=name)

# %%
#now seperately the 100 ligands and 1000 ligands
file_paths_1000 = [f'{path_prefix}{name}_full_equil.dat_0',f'{path_prefix}{name}_baseline_d062_1000.dat']
labels_1000 = ['v2','v1 0.62 g/mL 1000 ligands']
plot_multiple_steps_vs_density(file_paths_1000, labels_1000,0.876,name=name)
file_path_100 = [f for f in file_paths if f not in file_paths_1000]
labels_100 = [f for f in labels if f not in labels_1000]
plot_multiple_steps_vs_density(file_path_100, labels_100,0.876,name=name)

# %%
file_path_100
# Out:
# ['/localhome/cschiebroek/MDFP_VP/mdfptools/carl/equilibration_test_benzene_baseline_d062.dat',
#  '/localhome/cschiebroek/MDFP_VP/mdfptools/carl/equilibration_test_benzene_baseline_d095.dat',
#  '/localhome/cschiebroek/MDFP_VP/mdfptools/carl/equilibration_test_benzene_full_equil_n100.dat_0']

# %%
file_paths_fig1 = [file_path_100[0],file_path_100[-1]]
labels_fig1 = ['v1','v2']
plot_multiple_steps_vs_density(file_paths_fig1, labels_fig1,0.876,name=name)

# %%
#now v2 1000 vs 100 vs 256
file_paths = [f'{path_prefix}{name}_full_equil.dat_0',f'{path_prefix}{name}_full_equil_n100.dat_0',f'{path_prefix}{name}_full_equil_n256.dat_0']
labels = ['v2','v2 100 ligands','v2 256 ligands']
plot_multiple_steps_vs_density(file_paths, labels,0.876,name=name)

# %%
plot_multiple_steps_vs_density(file_paths[0:1], labels[0:1],0.876,name=name + ' 1000 ligands')

# %%
plot_multiple_steps_vs_density(file_paths[2:], labels[2:],0.876,name=name + ' 256 ligands')

# %%
plot_multiple_steps_vs_density(file_paths[1:2], labels[1:2],0.876,name=name + ' 100 ligands')

# %%
smiles = 'c1ccccc1'
rdk_pmd_water = Parameteriser.SolutionParameteriser.via_rdkit(smiles=smiles)
rdk_pmd_water
#save as pdb
# Out:
# /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/structure.py:1775: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[69], line 2
#       1 smiles = 'c1ccccc1'
# ----> 2 rdk_pmd_water = Parameteriser.SolutionParameteriser.via_rdkit(smiles=smiles)
#       3 rdk_pmd_water
#
# File /localhome/cschiebroek/MDFP_VP/mdfptools/carl/Parameteriser.py:241, in SolutionParameteriser.run(cls, smiles, mol, seed, solvent_smiles, allow_undefined_stereo, num_solvent, density, default_padding, box_scaleup_factor, **kwargs)
#     239 if cls.solvent_pmd is None:
#     240     try:
# --> 241         cls.solvent_pmd = parmed.load_file("/data/tip3p.prmtop") #TODO get this path instead of giving absolute path
#     244     except ValueError:
#     245         raise ValueError("Water file cannot be located")
#
# File /localhome/cschiebroek/.conda/envs/mdfp_carl/lib/python3.11/site-packages/parmed/formats/registry.py:166, in load_file(filename, *args, **kwargs)
#     164         assert f
#     165 elif not os.path.exists(filename):
# --> 166     raise FileNotFoundError('%s does not exist' % filename)
#     167 elif not os.access(filename, os.R_OK):
#     168     raise FileNotFoundError('%s does not have read permissions set' % filename)
#
# FileNotFoundError: /data/tip3p.prmtop does not exist

# %%
smiles = 'c1ccccc1'
rdk_pmd = Parameteriser.LiquidParameteriser.via_rdkit(smiles=smiles,density=0.62 * unit.gram/unit.milliliter,num_lig=1000)
SolutionSimulator.via_openmm(rdk_pmd, file_name = 'test_benzene_baseline_d062_1000', file_path = './',
                             platform = "CUDA", num_steps = 1 * 1)
name = "benzene"
file_paths = [f'{path_prefix}{name}_baseline_d062.dat', f'{path_prefix}{name}_baseline_d095.dat', f'{path_prefix}{name}_full_equil.dat_0',f'{path_prefix}{name}_baseline_d062_1000.dat']
labels = ['v1 0.62 g/mL', 'v1 0.95 g/mL', 'v2','v1 0.62 g/mL 1000 ligands']
plot_multiple_steps_vs_density(file_paths, labels,0.876,name=name)
