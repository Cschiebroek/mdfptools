# %%
#remove entries for model MultilinearRegression and descriptor RDKit_PhysChem for all seeds
query = """
DELETE FROM cs_mdfps_schema.model_descriptor_results
WHERE descriptor=%s AND model=%s
"""
conn = psycopg2.connect("dbname=cs_mdfps user=cschiebroek host=lebanon")
cur = conn.cursor()
cur.execute(query, ('RDKit_PhysChem', 'MultilinearRegression'))
conn.commit()

# %%
import psycopg2
import pandas as pd
import logging
import warnings
from utils.data_preprocessing import prepare_data, preprocess_data, get_features
from descriptors.rdkit_physchem_decriptors import calculate_RDKit_PhysChem_descriptors
from descriptors.mdfp import extract_mdfp_features
from models.linear_regression import MultilinearRegressionModel


# Add the new model to the dictionary of available models
model_classes = {
    'MultilinearRegression': MultilinearRegressionModel,
}

warnings.filterwarnings("ignore", category=FutureWarning)
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

descriptor_functions = {
    'RDKit_PhysChem': calculate_RDKit_PhysChem_descriptors,
    'MDFP': extract_mdfp_features,
}
 
descriptors_to_use = ['RDKit_PhysChem', 'MDFP','Counts',"NumHeavyAtoms","Counts_simple"]
models_to_evaluate = ['MultilinearRegression']
conn = psycopg2.connect("dbname=cs_mdfps user=cschiebroek host=lebanon")
df = prepare_data(conn,descriptors_to_use)
def store_results_in_db(conn, descriptor, model_name, seed, molregno, y_true, y_pred):
    query = """
    INSERT INTO cs_mdfps_schema.model_descriptor_results (descriptor, model, seed, molregno, y_true, y_pred) 
    VALUES (%s, %s, %s, %s, %s, %s)
    """
    cur = conn.cursor()
    cur.execute(query, (descriptor, model_name, seed, molregno, y_true, y_pred))
    conn.commit()
    cur.close()
predictions = {(descriptor, model_name): [] for descriptor in descriptors_to_use for model_name in models_to_evaluate}
y_list, molregno_list = [], []

for i in range(10):
    logging.info(f"Training and evaluating split {i+1}... \n \n \n")
    _, val_molregnos, train_y, val_y, df_train, df_val = preprocess_data(df, i)

    for descriptor in descriptors_to_use:
        logging.info(f"Extracting features for descriptor: {descriptor}")
        scale = False
        train_X, val_X = get_features(df_train=df_train, df_val=df_val, descriptor_name=descriptor, scale=scale)

        for model_name in models_to_evaluate:
            logging.info(f"Training and evaluating model: {model_name} with descriptor: {descriptor}")


            model_class = model_classes[model_name]
            model = model_class()
            model.train(train_X, train_y)
            y_pred = model.predict(val_X)
            y_true = val_y.tolist()
            if descriptor == 'RDKit_PhysChem':
                store_results_in_db(conn, descriptor, model_name, i, val_molregnos, val_y.tolist(), y_pred.tolist())

            assert len(y_pred) == len(y_true)
            molregno = val_molregnos
            predictions[(descriptor, model_name)].append(y_pred)

    y_list.append(y_true)
    molregno_list.append(molregno)

combined_titles = []
combined_preds = []
combined_reals = []
combined_molregnos = []

for descriptor in descriptors_to_use:
    for model_name in models_to_evaluate:
        combined_titles.append(f"{model_name} ({descriptor})")
        combined_preds.append(predictions[(descriptor, model_name)])
        combined_reals.append(y_list)
        combined_molregnos.append(molregno_list)
# Out:
# 2024-11-12 16:19:27,781 - INFO - Loading data from the database...
# 2024-11-12 16:19:28,133 - INFO - Calculating descriptors...
# 2024-11-12 16:19:28,133 - INFO - Fetching RDKit descriptors from the database...
# 2024-11-12 16:19:29,029 - INFO - Merging RDKit descriptors with the main dataframe...
# 2024-11-12 16:19:29,441 - INFO - Index(['molregno', 'conf_id', 'vp_log10_pa', 'mdfp', 'molblock',
#        'md_experiment_uuid', 'confgen_uuid', 'Ipc', 'qed', 'Chi0',
#        ...
#        'water_intra_ene_median', 'water_total_ene_mean', 'water_total_ene_std',
#        'water_total_ene_median', 'water_rgyr_mean', 'water_rgyr_std',
#        'water_rgyr_median', 'water_sasa_mean', 'water_sasa_std',
#        'water_sasa_median'],
#       dtype='object', length=257)
# 2024-11-12 16:19:29,443 - INFO - Data loaded and descriptors calculated, dropping NaNs...
# 2024-11-12 16:19:29,446 - INFO - Dropped 0 rows due to missing values.
# 2024-11-12 16:19:29,448 - INFO - Training and evaluating split 1...
#
#
#
# 2024-11-12 16:19:29,449 - INFO - Splitting data into training and testing sets...
# 2024-11-12 16:19:29,454 - INFO - Extracting features for descriptor: RDKit_PhysChem
# 2024-11-12 16:19:29,829 - INFO - Training and evaluating model: MultilinearRegression with descriptor: RDKit_PhysChem
# 2024-11-12 16:19:29,882 - INFO - Extracting features for descriptor: MDFP
# 2024-11-12 16:19:30,251 - INFO - Training and evaluating model: MultilinearRegression with descriptor: MDFP
# 2024-11-12 16:19:30,255 - INFO - Extracting features for descriptor: Counts
# 2024-11-12 16:19:30,262 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts
# 2024-11-12 16:19:30,266 - INFO - Extracting features for descriptor: NumHeavyAtoms
# 2024-11-12 16:19:30,268 - INFO - Training and evaluating model: MultilinearRegression with descriptor: NumHeavyAtoms
# 2024-11-12 16:19:30,271 - INFO - Extracting features for descriptor: Counts_simple
# 2024-11-12 16:19:30,276 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts_simple
# 2024-11-12 16:19:30,279 - INFO - Training and evaluating split 2...
#
#
#
# 2024-11-12 16:19:30,280 - INFO - Splitting data into training and testing sets...
# 2024-11-12 16:19:30,284 - INFO - Extracting features for descriptor: RDKit_PhysChem
# 2024-11-12 16:19:30,674 - INFO - Training and evaluating model: MultilinearRegression with descriptor: RDKit_PhysChem
# 2024-11-12 16:19:30,708 - INFO - Extracting features for descriptor: MDFP
# 2024-11-12 16:19:31,081 - INFO - Training and evaluating model: MultilinearRegression with descriptor: MDFP
# 2024-11-12 16:19:31,085 - INFO - Extracting features for descriptor: Counts
# 2024-11-12 16:19:31,092 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts
# 2024-11-12 16:19:31,096 - INFO - Extracting features for descriptor: NumHeavyAtoms
# 2024-11-12 16:19:31,098 - INFO - Training and evaluating model: MultilinearRegression with descriptor: NumHeavyAtoms
# 2024-11-12 16:19:31,101 - INFO - Extracting features for descriptor: Counts_simple
# 2024-11-12 16:19:31,106 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts_simple
# 2024-11-12 16:19:31,109 - INFO - Training and evaluating split 3...
#
#
#
# 2024-11-12 16:19:31,110 - INFO - Splitting data into training and testing sets...
# 2024-11-12 16:19:31,114 - INFO - Extracting features for descriptor: RDKit_PhysChem
# 2024-11-12 16:19:31,508 - INFO - Training and evaluating model: MultilinearRegression with descriptor: RDKit_PhysChem
# 2024-11-12 16:19:31,543 - INFO - Extracting features for descriptor: MDFP
# 2024-11-12 16:19:31,914 - INFO - Training and evaluating model: MultilinearRegression with descriptor: MDFP
# 2024-11-12 16:19:31,918 - INFO - Extracting features for descriptor: Counts
# 2024-11-12 16:19:31,925 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts
# 2024-11-12 16:19:31,929 - INFO - Extracting features for descriptor: NumHeavyAtoms
# 2024-11-12 16:19:31,931 - INFO - Training and evaluating model: MultilinearRegression with descriptor: NumHeavyAtoms
# 2024-11-12 16:19:31,934 - INFO - Extracting features for descriptor: Counts_simple
# 2024-11-12 16:19:31,939 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts_simple
# 2024-11-12 16:19:31,942 - INFO - Training and evaluating split 4...
#
#
#
# 2024-11-12 16:19:31,943 - INFO - Splitting data into training and testing sets...
# 2024-11-12 16:19:31,947 - INFO - Extracting features for descriptor: RDKit_PhysChem
# 2024-11-12 16:19:32,346 - INFO - Training and evaluating model: MultilinearRegression with descriptor: RDKit_PhysChem
# 2024-11-12 16:19:32,381 - INFO - Extracting features for descriptor: MDFP
# 2024-11-12 16:19:32,753 - INFO - Training and evaluating model: MultilinearRegression with descriptor: MDFP
# 2024-11-12 16:19:32,757 - INFO - Extracting features for descriptor: Counts
# 2024-11-12 16:19:32,765 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts
# 2024-11-12 16:19:32,769 - INFO - Extracting features for descriptor: NumHeavyAtoms
# 2024-11-12 16:19:32,771 - INFO - Training and evaluating model: MultilinearRegression with descriptor: NumHeavyAtoms
# 2024-11-12 16:19:32,774 - INFO - Extracting features for descriptor: Counts_simple
# 2024-11-12 16:19:32,779 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts_simple
# 2024-11-12 16:19:32,783 - INFO - Training and evaluating split 5...
#
#
#
# 2024-11-12 16:19:32,783 - INFO - Splitting data into training and testing sets...
# 2024-11-12 16:19:32,787 - INFO - Extracting features for descriptor: RDKit_PhysChem
# 2024-11-12 16:19:33,180 - INFO - Training and evaluating model: MultilinearRegression with descriptor: RDKit_PhysChem
# 2024-11-12 16:19:33,215 - INFO - Extracting features for descriptor: MDFP
# 2024-11-12 16:19:33,590 - INFO - Training and evaluating model: MultilinearRegression with descriptor: MDFP
# 2024-11-12 16:19:33,594 - INFO - Extracting features for descriptor: Counts
# 2024-11-12 16:19:33,602 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts
# 2024-11-12 16:19:33,605 - INFO - Extracting features for descriptor: NumHeavyAtoms
# 2024-11-12 16:19:33,607 - INFO - Training and evaluating model: MultilinearRegression with descriptor: NumHeavyAtoms
# 2024-11-12 16:19:33,610 - INFO - Extracting features for descriptor: Counts_simple
# 2024-11-12 16:19:33,615 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts_simple
# 2024-11-12 16:19:33,618 - INFO - Training and evaluating split 6...
#
#
#
# 2024-11-12 16:19:33,619 - INFO - Splitting data into training and testing sets...
# 2024-11-12 16:19:33,623 - INFO - Extracting features for descriptor: RDKit_PhysChem
# 2024-11-12 16:19:34,015 - INFO - Training and evaluating model: MultilinearRegression with descriptor: RDKit_PhysChem
# 2024-11-12 16:19:34,050 - INFO - Extracting features for descriptor: MDFP
# 2024-11-12 16:19:34,421 - INFO - Training and evaluating model: MultilinearRegression with descriptor: MDFP
# 2024-11-12 16:19:34,425 - INFO - Extracting features for descriptor: Counts
# 2024-11-12 16:19:34,432 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts
# 2024-11-12 16:19:34,436 - INFO - Extracting features for descriptor: NumHeavyAtoms
# 2024-11-12 16:19:34,438 - INFO - Training and evaluating model: MultilinearRegression with descriptor: NumHeavyAtoms
# 2024-11-12 16:19:34,441 - INFO - Extracting features for descriptor: Counts_simple
# 2024-11-12 16:19:34,446 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts_simple
# 2024-11-12 16:19:34,449 - INFO - Training and evaluating split 7...
#
#
#
# 2024-11-12 16:19:34,450 - INFO - Splitting data into training and testing sets...
# 2024-11-12 16:19:34,454 - INFO - Extracting features for descriptor: RDKit_PhysChem
# 2024-11-12 16:19:34,848 - INFO - Training and evaluating model: MultilinearRegression with descriptor: RDKit_PhysChem
# 2024-11-12 16:19:34,882 - INFO - Extracting features for descriptor: MDFP
# 2024-11-12 16:19:35,256 - INFO - Training and evaluating model: MultilinearRegression with descriptor: MDFP
# 2024-11-12 16:19:35,260 - INFO - Extracting features for descriptor: Counts
# 2024-11-12 16:19:35,267 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts
# 2024-11-12 16:19:35,271 - INFO - Extracting features for descriptor: NumHeavyAtoms
# 2024-11-12 16:19:35,274 - INFO - Training and evaluating model: MultilinearRegression with descriptor: NumHeavyAtoms
# 2024-11-12 16:19:35,277 - INFO - Extracting features for descriptor: Counts_simple
# 2024-11-12 16:19:35,282 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts_simple
# 2024-11-12 16:19:35,285 - INFO - Training and evaluating split 8...
#
#
#
# 2024-11-12 16:19:35,285 - INFO - Splitting data into training and testing sets...
# 2024-11-12 16:19:35,290 - INFO - Extracting features for descriptor: RDKit_PhysChem
# 2024-11-12 16:19:35,688 - INFO - Training and evaluating model: MultilinearRegression with descriptor: RDKit_PhysChem
# 2024-11-12 16:19:35,726 - INFO - Extracting features for descriptor: MDFP
# 2024-11-12 16:19:36,098 - INFO - Training and evaluating model: MultilinearRegression with descriptor: MDFP
# 2024-11-12 16:19:36,102 - INFO - Extracting features for descriptor: Counts
# 2024-11-12 16:19:36,110 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts
# 2024-11-12 16:19:36,113 - INFO - Extracting features for descriptor: NumHeavyAtoms
# 2024-11-12 16:19:36,115 - INFO - Training and evaluating model: MultilinearRegression with descriptor: NumHeavyAtoms
# 2024-11-12 16:19:36,118 - INFO - Extracting features for descriptor: Counts_simple
# 2024-11-12 16:19:36,123 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts_simple
# 2024-11-12 16:19:36,126 - INFO - Training and evaluating split 9...
#
#
#
# 2024-11-12 16:19:36,127 - INFO - Splitting data into training and testing sets...
# 2024-11-12 16:19:36,131 - INFO - Extracting features for descriptor: RDKit_PhysChem
# 2024-11-12 16:19:36,523 - INFO - Training and evaluating model: MultilinearRegression with descriptor: RDKit_PhysChem
# 2024-11-12 16:19:36,558 - INFO - Extracting features for descriptor: MDFP
# 2024-11-12 16:19:36,926 - INFO - Training and evaluating model: MultilinearRegression with descriptor: MDFP
# 2024-11-12 16:19:36,930 - INFO - Extracting features for descriptor: Counts
# 2024-11-12 16:19:36,938 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts
# 2024-11-12 16:19:36,941 - INFO - Extracting features for descriptor: NumHeavyAtoms
# 2024-11-12 16:19:36,944 - INFO - Training and evaluating model: MultilinearRegression with descriptor: NumHeavyAtoms
# 2024-11-12 16:19:36,946 - INFO - Extracting features for descriptor: Counts_simple
# 2024-11-12 16:19:36,951 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts_simple
# 2024-11-12 16:19:36,955 - INFO - Training and evaluating split 10...
#
#
#
# 2024-11-12 16:19:36,955 - INFO - Splitting data into training and testing sets...
# 2024-11-12 16:19:36,959 - INFO - Extracting features for descriptor: RDKit_PhysChem
# 2024-11-12 16:19:37,353 - INFO - Training and evaluating model: MultilinearRegression with descriptor: RDKit_PhysChem
# 2024-11-12 16:19:37,389 - INFO - Extracting features for descriptor: MDFP
# 2024-11-12 16:19:37,762 - INFO - Training and evaluating model: MultilinearRegression with descriptor: MDFP
# 2024-11-12 16:19:37,766 - INFO - Extracting features for descriptor: Counts
# 2024-11-12 16:19:37,773 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts
# 2024-11-12 16:19:37,776 - INFO - Extracting features for descriptor: NumHeavyAtoms
# 2024-11-12 16:19:37,779 - INFO - Training and evaluating model: MultilinearRegression with descriptor: NumHeavyAtoms
# 2024-11-12 16:19:37,781 - INFO - Extracting features for descriptor: Counts_simple
# 2024-11-12 16:19:37,786 - INFO - Training and evaluating model: MultilinearRegression with descriptor: Counts_simple

# %%
from utils.visualization import density_plots

# density_plots(reals_list=combined_reals, predictions_list=combined_preds, molregnos_list=combined_molregnos,
#                 print_stats=True, bounds=None, title=combined_titles,
#                 name="Simple", dims=(3,2), thresholds=1)

# %%
combined_titles
# Out:
# ['MultilinearRegression (RDKit_PhysChem)',
#  'MultilinearRegression (MDFP)',
#  'MultilinearRegression (Counts)',
#  'MultilinearRegression (NumHeavyAtoms)',
#  'MultilinearRegression (Counts_simple)']

# %%
#and change order; first numbeavyatoms, then counts, then rdkit_physchem
combined_titles_no_mdfp = [combined_titles[3],combined_titles[4],combined_titles[0]]
combined_reals_no_mdfp = [combined_reals[3],combined_reals[4],combined_reals[0]]
combined_preds_no_mdfp = [combined_preds[3],combined_preds[4],combined_preds[0]]
combined_molregnos_no_mdfp = [combined_molregnos[3],combined_molregnos[4],combined_molregnos[0]]

#changes names from MultilinearRegression to Ordinary Least Squares
combined_titles_no_mdfp[0] = combined_titles_no_mdfp[0].replace("MultilinearRegression","Ordinary Least Squares")
combined_titles_no_mdfp[1] = combined_titles_no_mdfp[1].replace("MultilinearRegression","Ordinary Least Squares")
combined_titles_no_mdfp[2] = combined_titles_no_mdfp[2].replace("MultilinearRegression","Ordinary Least Squares")
combined_titles_no_mdfp[1] = combined_titles_no_mdfp[1].replace("Counts_simple","Counts")
combined_titles_no_mdfp[2] = combined_titles_no_mdfp[2].replace("RDKit_PhysChem","All")


# density_plots(reals_list=combined_reals_no_mdfp, predictions_list=combined_preds_no_mdfp, molregnos_list=combined_molregnos_no_mdfp,
#                 print_stats=True, bounds=None, title=combined_titles_no_mdfp,
#                 name="Simple", dims=(1,3), thresholds=1)

# %%
df_numeric = df.select_dtypes(include=['float64', 'int64'])
corr = df_numeric.corr()
# corr.style.background_gradient(cmap='coolwarm')

# %%
#and do a subset of these, with only those that have a corr of at least (abs) 0.3 to vp_log10_pa
corr_vp = corr["vp_log10_pa"]
corr_vp = corr_vp[abs(corr_vp) > 0.3]
absolute_corr_vp = abs(corr_vp)
absolute_corr_vp = absolute_corr_vp.sort_values(ascending=False)
for factor in absolute_corr_vp.index[2:]:
    print(f"Correlation between vp_log10_pa and {factor}: {corr_vp[factor]}")
# Out:
# Correlation between vp_log10_pa and MolMR: -0.848489494985087
# Correlation between vp_log10_pa and LabuteASA: -0.8355685873902197
# Correlation between vp_log10_pa and Chi1: -0.8306929717690472
# Correlation between vp_log10_pa and NumHeavyAtoms: -0.8100781236883946
# Correlation between vp_log10_pa and HeavyAtomCount: -0.8100781236883946
# Correlation between vp_log10_pa and Chi0v: -0.805276382784739
# Correlation between vp_log10_pa and AvgIpc: -0.7905094889563636
# Correlation between vp_log10_pa and BertzCT: -0.7804293005952412
# Correlation between vp_log10_pa and Chi1v: -0.7777188689461293
# Correlation between vp_log10_pa and water_sasa_mean: -0.7737424695193129
# Correlation between vp_log10_pa and water_sasa_median: -0.771180628248295
# Correlation between vp_log10_pa and Chi0: -0.7678843156220447
# Correlation between vp_log10_pa and water_rgyr_mean: -0.7542551042445687
# Correlation between vp_log10_pa and ExactMolWt: -0.7491918666478078
# Correlation between vp_log10_pa and NumValenceElectrons: -0.7488726212288871
# Correlation between vp_log10_pa and MolWt: -0.748340386909598
# Correlation between vp_log10_pa and water_rgyr_median: -0.7438072608686069
# Correlation between vp_log10_pa and Chi0n: -0.7413771237085368
# Correlation between vp_log10_pa and Chi3v: -0.7317382375802544
# Correlation between vp_log10_pa and HeavyAtomMolWt: -0.7288512693954251
# Correlation between vp_log10_pa and Chi2v: -0.7234624490420879
# Correlation between vp_log10_pa and Chi4v: -0.7194252206760587
# Correlation between vp_log10_pa and Chi1n: -0.7158680634093751
# Correlation between vp_log10_pa and Chi3n: -0.7096384817396849
# Correlation between vp_log10_pa and Chi4n: -0.7066351513679338
# Correlation between vp_log10_pa and Chi2n: -0.6825712610774428
# Correlation between vp_log10_pa and water_total_lj_std: -0.6783018418642763
# Correlation between vp_log10_pa and Kappa1: -0.6782446543218283
# Correlation between vp_log10_pa and NumAromaticRings: -0.6194312597154086
# Correlation between vp_log10_pa and water_intra_lj_mean: -0.6173536508337897
# Correlation between vp_log10_pa and water_intra_lj_median: -0.6141378350147355
# Correlation between vp_log10_pa and RingCount: -0.5963867658145693
# Correlation between vp_log10_pa and MolLogP: -0.5846675143232786
# Correlation between vp_log10_pa and NumAromaticCarbocycles: -0.5836262898495346
# Correlation between vp_log10_pa and fr_benzene: -0.5836262898495346
# Correlation between vp_log10_pa and SMR_VSA7: -0.5489251827334652
# Correlation between vp_log10_pa and PEOE_VSA6: -0.5251191774039785
# Correlation between vp_log10_pa and Kappa2: -0.5135187600793859
# Correlation between vp_log10_pa and water_intra_lj_std: -0.5123157761277138
# Correlation between vp_log10_pa and water_intra_ene_std: -0.5101910696435215
# Correlation between vp_log10_pa and SMR_VSA10: -0.5047532328078524
# Correlation between vp_log10_pa and water_total_ene_std: -0.47472190824269445
# Correlation between vp_log10_pa and SlogP_VSA6: -0.4687919755894948
# Correlation between vp_log10_pa and FpDensityMorgan1: 0.45675294692121027
# Correlation between vp_log10_pa and BCUT2D_LOGPHI: -0.4416101937681904
# Correlation between vp_log10_pa and VSA_EState6: -0.4410031315342825
# Correlation between vp_log10_pa and EState_VSA3: -0.4378384196887546
# Correlation between vp_log10_pa and PEOE_VSA9: -0.43496051253466594
# Correlation between vp_log10_pa and FractionCSP3: 0.43249807380639693
# Correlation between vp_log10_pa and water_total_lj_median: 0.4258230242379396
# Correlation between vp_log10_pa and water_total_lj_mean: 0.4254074148835064
# Correlation between vp_log10_pa and SMR_VSA9: -0.4210407906281937
# Correlation between vp_log10_pa and water_sasa_std: -0.4168994391858476
# Correlation between vp_log10_pa and EState_VSA9: -0.40739285731447505
# Correlation between vp_log10_pa and NumRotatableBonds: -0.39598168035498277
# Correlation between vp_log10_pa and NumRotatableBonds_y: -0.39598168035498277
# Correlation between vp_log10_pa and SlogP_VSA1: -0.3869959802878848
# Correlation between vp_log10_pa and NOCount: -0.38524768114906044
# Correlation between vp_log10_pa and PEOE_VSA8: -0.3822903105095396
# Correlation between vp_log10_pa and VSA_EState10: -0.3815559398942005
# Correlation between vp_log10_pa and SlogP_VSA7: -0.3805261920584078
# Correlation between vp_log10_pa and BCUT2D_CHGLO: 0.37598851889283635
# Correlation between vp_log10_pa and SlogP_VSA12: -0.3749392057809019
# Correlation between vp_log10_pa and EState_VSA2: -0.3738128687426943
# Correlation between vp_log10_pa and EState_VSA6: -0.3674105828362807
# Correlation between vp_log10_pa and water_rgyr_std: -0.3657983525301492
# Correlation between vp_log10_pa and TPSA: -0.3654965200916443
# Correlation between vp_log10_pa and HallKierAlpha: 0.3646358273785597
# Correlation between vp_log10_pa and NumHAcceptors: -0.3629136038871597
# Correlation between vp_log10_pa and PEOE_VSA7: -0.36202673845827216
# Correlation between vp_log10_pa and SlogP_VSA8: -0.35705899213578646
# Correlation between vp_log10_pa and EState_VSA5: -0.3440353010768069
# Correlation between vp_log10_pa and SlogP_VSA11: -0.3433100446556622
# Correlation between vp_log10_pa and NumCl: -0.3309703730933872
# Correlation between vp_log10_pa and fr_unbrch_alkane: -0.33044321978951263
# Correlation between vp_log10_pa and water_total_ene_mean: 0.3225711206392151
# Correlation between vp_log10_pa and water_total_ene_median: 0.3225033950733553
# Correlation between vp_log10_pa and PEOE_VSA1: -0.31773903253278457
# Correlation between vp_log10_pa and water_total_crf_std: -0.3177356550718819
# Correlation between vp_log10_pa and fr_bicyclic: -0.31715438051388545
# Correlation between vp_log10_pa and MinAbsEStateIndex: 0.3138922680710072
# Correlation between vp_log10_pa and NumN: -0.31276085821097627
# Correlation between vp_log10_pa and NumHeteroatoms: -0.3105974750809835
# Correlation between vp_log10_pa and NumO: -0.304444470503972
# Correlation between vp_log10_pa and PEOE_VSA10: -0.3024532250504894
# Correlation between vp_log10_pa and VSA_EState7: -0.300673359578496
# Correlation between vp_log10_pa and FpDensityMorgan2: 0.30038488282830855
