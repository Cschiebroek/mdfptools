# %%
atom_types = [
    "Const",
    "B",
    "C sp3",
    "C sp2",
    "C aromatic",
    "C sp",
    "N sp3",
    "N sp2",
    "N aromatic",
    "N(+) sp2",
    "N(+) sp",
    "O(prim)",
    "O(sec)",
    "O(tert)",
    "O",
    "P3",
    "P4",
    "S2",
    "S4",
    "S6",
    "Si"
]

unique_neighbours = [
    "HN2",
    "BN2",
    "BO2",
    "C2N",
    "C2O",
    "C2S",
    "CO2",
    "O3",
    "S3",
    "H3B",
    "H3C",
    "H3N",
    "H3N(+)",
    "H3O",
    "H3S",
    "H3P",
    "H3Si",
    "H2C2",
    "H2CN",
    "H2CN(+)",
    "H2CO",
    "H2CP",
    "H2CS",
    "H2CF",
    "H2CCl",
    "H2CBr",
    "H2CJ",
    "H2CSi",
    "H2N2",
    "H2NO",
    "H2NS",
    "H2O2",
    "H2OF",
    "H2OCl",
    "H2S2",
    "HC3",
    "HC2N",
    "HC2N(+)",
    "HC2O",
    "HC2S",
    "HC2F",
    "HC2Cl",
    "HC2Br",
    "HC2J",
    "HCN2",
    "HCNO",
    "HCNS",
    "HCO2",
    "HCOBr",
    "HCF2",
    "HCFCl",
    "HCCl2",
    "HCClBr",
    "HCBr2",
    "HOF2",
    "C4",
    "C3N",
    "C3N(+)",
    "C3O",
    "C3S",
    "C3Si",
    "C3Cl",
    "C3Br",
    "C3F",
    "C2O2",
    "C2OF",
    "C2F2",
    "C2FCl",
    "C2Cl2",
    "CNF2",
    "CNF2(+)",
    "CNCl2",
    "COF2",
    "CSF2",
    "CF3",
    "CF2Cl",
    "CF2Br",
    "CFCl2",
    "CFClBr",
    "CCl3",
    "CCl2Br",
    "NF3",
    "OF3",
    "O2F2",
    "S2F2",
    "SF3",
    "SCl3",
    "PF3",
    "H2=C",
    "HC=C",
    "HC=N",
    "HC=O",
    "H=CN",
    "H=CO",
    "H=CS",
    "H=CP",
    "H=CF",
    "H=CCl",
    "H=CBr",
    "H=CJ",
    "HN=N",
    "HN=O",
    "HO=O",
    "C2=C",
    "C2=N",
    "C=CN",
    "C2=O",
    "C=CO",
    "C=CP",
    "C=CS",
    "C=CF",
    "C=CCl",
    "CN=N",
    "CN=O",
    "C=NS",
    "CO=O",
    "C=OCl",
    "C=OBr",
    "C=OJ",
    "=CF2",
    "=CFCl",
    "=CFBr",
    "=CCl2",
    "=CBr2",
    "N2=N",
    "N2=O",
    "N=NS",
    "N2=S",
    "NO=O",
    "N=OS",
    "=NOS",
    "NS=S",
    "O2=O",
    "H:C2",
    "H:C:N",
    "H:N2",
    ":C3",
    "C:C2",
    "C:C:N",
    ":C2N",
    ":C2N(+)",
    ":C2:N",
    ":C2O",
    ":C2P",
    ":C2S",
    ":C2F",
    ":C2Cl",
    ":C2Br",
    ":C2J",
    ":C2Si",
    "C:N2",
    ":C:NO",
    ":C:NCl",
    "N:N2",
    ":N2O",
    ":N2S",
    ":N2Cl",
    "H#C",
    "C#C",
    "=C2",
    "C#N",
    "=N=O",
    "=N=S",
    "HB2",
    "H2C",
    "H2C(pi)",
    "H2N",
    "HC2",
    "HC2(pi)",
    "HC2(2pi)",
    "HCN",
    "HCN(pi)",
    "HCN(2pi)",
    "HCP(pi)",
    "HCS(pi)",
    "B2C",
    "BC2",
    "C3",
    "C3(pi)",
    "C3(2pi)",
    "C3(3pi)",
    "C2N(pi)",
    "C2N(2pi)",
    "C2N(3pi)",
    "C2O",
    "C2S",
    "C2S(pi)",
    "C2S(2pi)",
    "C2P",
    "C2F(pi)",
    "CF2",
    "CSi2",
    "SF2",
    "C=C",
    "C=N",
    "C=N(+)",
    "=CN",
    "=CO",
    "=CS",
    "N=N",
    "N=O",
    "=NP(+)",
    "O=O",
    ":C2",
    "CO=O(-)",
    "O2=O(-)",
    "=N2(-)",
    "HC",
    "HC(pi)",
    "HO",
    "BC",
    "BP",
    "C2",
    "C2(pi)",
    "C2(2pi)",
    "CN",
    "CN(pi)",
    "CN(2pi)",
    "CN(+)(pi)",
    "CO",
    "CO(pi)",
    "CS",
    "CS(pi)",
    "CP",
    "CP(pi)",
    "CSi",
    "OS",
    "S2",
    "Si2",
    "HC2",
    "C2N",
    "C2O",
    "C2S",
    "CN2",
    "CS2",
    "HO2=O",
    "C3=S",
    "CO2=O",
    "CO2=S",
    "CO=OS",
    "COS=S",
    "N3=O",
    "NO=OS",
    "N=OF2",
    "O3=O",
    "O3=S",
    "O2=OS",
    "O=OS2",
    "O2S=S",
    "HC",
    "HS",
    "HP",
    "C2",
    "C2(pi)",
    "C2(2pi)",
    "CN",
    "CN(2pi)",
    "CS",
    "CP",
    "N2",
    "NCl",
    "P2",
    "C2=O",
    "C2=O2",
    "C2O2",
    "C2F2",
    "CO=O2",
    "CN=O2",
    "NO=O2",
    "N=O2Cl",
    "O2=O",
    "O2=O2",
    "O=O2F",
    "C2F4",
    "O2F4",
    "OF5",
    "H3C",
    "H3N",
    "H3S",
    "H3Si",
    "H2C2",
    "H2Si2",
    "HC2O",
    "HC2S",
    "HC2J",
    "HCCl2",
    "HO3",
    "C4",
    "C3O",
    "C3S",
    "C3Cl",
    "C3Si",
    "C2O2",
    "C2F2",
    "C2Cl2",
    "CF3",
    "CCl3",
    "O4",
    "(COH)n",
    "(COOH)n"
]

# %%
atom_types_to_smarts = {
    "Const" : "*",
    "B" : "[#5]",
    "C sp3" : "[#6;X4]",
    "C sp2" : "[#6;X3]",
    "C aromatic": "c",
    "C sp" : "[#6;X2]",
    "N sp3" : "[#7;X4]",
    "N sp2" : "[#7;X3]",
    "N aromatic" : "n",
    "N(+) sp2" : "[#7;X3;+]",
    "N(+) sp" : "[#7;X2;+]",
    "O" : "[#8]",
    "P3" : "[#15;X3]",
    "P4" : "[#15;X4]",
    "S2" : "[#16;X2]",
    "S4" : "[#16;X4]",
    "S6" : "[#16;X6]",
    "Si" : "[#14]"

}

# %%
#check
from rdkit import Chem
mol_sp2 = Chem.MolFromSmiles("C=C")
print(mol_sp2.HasSubstructMatch(Chem.MolFromSmarts(atom_types_to_smarts["C sp2"])))
mol_sp = Chem.MolFromSmiles("C#C")
print(mol_sp.HasSubstructMatch(Chem.MolFromSmarts(atom_types_to_smarts["C sp"])))
# Out:
# True
# True

# %%
atom_types_to_smarts = {
    "Const": "*",
    "B": "[#5]",
    "C sp3": "[#6;X4]",
    "C sp2": "[#6;X3]",
    "C aromatic": "c",
    "C sp": "[#6;X2]",
    "N sp3": "[#7;X4]",
    "N sp2": "[#7;X3]",
    "N aromatic": "n",
    "N(+) sp2": "[#7;X3;+]",
    "N(+) sp": "[#7;X2;+]",
    "O": "[#8]",
    "P3": "[#15;X3]",
    "P4": "[#15;X4]",
    "S2": "[#16;X2]",
    "S4": "[#16;X4]",
    "S6": "[#16;X6]",
    "Si": "[#14]"
}

# Neighbors
neighbors_to_smarts = {
    "HN2": "[#7;H2]",
    "BN2": "[#5;N2]",
    "BO2": "[#5;O2]",
    "C2N": "[#6;X2;N]",
    "C2O": "[#6;X2;O]",
    "C2S": "[#6;X2;S]",
    "CO2": "[#6;O2]",
    "O3": "[#8;X3]",
    "S3": "[#16;X3]",
    "H3B": "[#1;H3]",
    "H3C": "[#6;X4;H3]",
    "H3N": "[#7;X4;H3]",
    "H3N(+)": "[#7;X4;H3;+]",
    "H3O": "[#8;X2;H3]",
    "H3S": "[#16;X2;H3]",
    "H3P": "[#15;X3;H3]",
    "H3Si": "[#14;X4;H3]",
    "H2C2": "[#6;X4;H2;C]",
    "H2CN": "[#6;X4;H2;C;N]",
    "H2CN(+)": "[#6;X4;H2;C;N;+]",
    "H2CO": "[#6;X4;H2;C;O]",
    "H2CP": "[#6;X4;H2;C;P]",
    "H2CS": "[#6;X4;H2;C;S]",
    "H2CF": "[#6;X4;H2;C;F]",
    "H2CCl": "[#6;X4;H2;C;Cl]",
    "H2CBr": "[#6;X4;H2;C;Br]",
    "H2CJ": "[#6;X4;H2;C;I]",
    "H2CSi": "[#6;X4;H2;C;Si]",
    "H2N2": "[#6;X4;H2;N2]",
    "H2NO": "[#6;X4;H2;N;O]",
    "H2NS": "[#6;X4;H2;N;S]",
    "H2O2": "[#6;X4;H2;O2]",
    "H2OF": "[#6;X4;H2;O;F]",
    "H2OCl": "[#6;X4;H2;O;Cl]",
    "H2S2": "[#6;X4;H2;S2]",
    "HC3": "[#6;X4;H;C3]",
    "HC2N": "[#6;X4;H;C;N]",
    "HC2N(+)": "[#6;X4;H;C;N;+]",
    "HC2O": "[#6;X4;H;C;O]",
    "HC2S": "[#6;X4;H;C;S]",
    "HC2F": "[#6;X4;H;C;F]",
    "HC2Cl": "[#6;X4;H;C;Cl]",
    "HC2Br": "[#6;X4;H;C;Br]",
    "HC2J": "[#6;X4;H;C;I]",
    "HCN2": "[#6;X4;H;C;N2]",
    "HCNO": "[#6;X4;H;C;N;O]",
    "HCNS": "[#6;X4;H;C;N;S]",
    "HCO2": "[#6;X4;H;C;O2]",
    "HCOBr": "[#6;X4;H;C;O;Br]",
    "HCF2": "[#6;X4;H;C;F2]",
    "HCFCl": "[#6;X4;H;C;F;Cl]",
    "HCCl2": "[#6;X4;H;C;Cl2]",
    "HCClBr": "[#6;X4;H;C;Cl;Br]",
    "HCBr2": "[#6;X4;H;C;Br2]",
    "HOF2": "[#6;X4;H;O;F2]",
    "C4": "[#6;X4;C3]",
    "C3N": "[#6;X4;C2;N]",
    "C3N(+)": "[#6;X4;C2;N;+]",
    "C3O": "[#6;X4;C2;O]",
    "C3S": "[#6;X4;C2;S]",
    "C3Si": "[#6;X4;C2;Si]",
    "C3Cl": "[#6;X4;C2;Cl]",
    "C3Br": "[#6;X4;C2;Br]",
    "C3F": "[#6;X4;C2;F]",
    "C2O2": "[#6;X4;C;O2]",
    "C2OF": "[#6;X4;C;O;F]",
    "C2F2": "[#6;X4;C;F2]",
    "C2FCl": "[#6;X4;C;F;Cl]",
    "C2Cl2": "[#6;X4;C;Cl2]",
    "CNF2": "[#6;X4;C;N;F2]",
    "CNF2(+)": "[#6;X4;C;N;F2;+]",
    "CNCl2": "[#6;X4;C;N;Cl2]",
    "COF2": "[#6;X4;C;O;F2]",
    "CSF2": "[#6;X4;C;S;F2]",
    "CF3": "[#6;X4;C;F3]",
    "CF2Cl": "[#6;X4;C;F2;Cl]",
    "CF2Br": "[#6;X4;C;F2;Br]",
    "CFCl2": "[#6;X4;C;F;Cl2]",
    "CFClBr": "[#6;X4;C;F;Cl;Br]",
    "CCl3": "[#6;X4;C;Cl3]",
    "CCl2Br": "[#6;X4;C;Cl2;Br]",
    "NF3": "[#7;X3;F3]",
    "OF3": "[#8;X2;F3]",
    "O2F2": "[#8;X2;F2]",
    "S2F2": "[#16;X2;F2]",
    "SF3": "[#16;X2;F3]",
    "SCl3": "[#16;X2;Cl3]",
    "PF3": "[#15;X3;F3]",
    "H2=C": "[#6;X2;H2]=[#6;X2]",
    "HC=C": "[#6;X2;H]=[#6;X2]",
    "HC=N": "[#6;X2;H]=[#7;X2]",
    "HC=O": "[#6;X2;H]=[#8;X2]",
    "H=CN": "[#6;X3;H][#7;X2]",
    "H=CO": "[#6;X3;H][#8;X2]",
    "H=CS": "[#6;X3;H][#16;X2]",
    "H=CP": "[#6;X3;H][#15;X3]",
    "H=CF": "[#6;X3;H][#6;X2;F]",
    "H=CCl": "[#6;X3;H][#6;X2;Cl]",

    "H=CBr": "[#6;X3;H][#6;X2;Br]",
    "H=CJ": "[#6;X3;H][#6;X2;I]",
    "HN=N": "[#7;X2;H][#7;X2]",
    "HN=O": "[#7;X2;H][#8;X2]",
    "HO=O": "[#8;X2;H][#8;X2]",
    "C2=C": "[#6;X3;H][#6;X3]",
    "C2=N": "[#6;X3;H][#7;X3]",
    "C=CN": "[#6;X2;H]=[#6;X3;N]",
    "C2=O": "[#6;X3;H][#8;X3]",
    "C=CO": "[#6;X2;H]=[#8;X3]",
    "C=CP": "[#6;X2;H]=[#15;X3]",
    "C=CS": "[#6;X2;H]=[#16;X3]",
    "C=CF": "[#6;X2;H]=[#6;X2;F]",
    "C=CCl": "[#6;X2;H]=[#6;X2;Cl]",
    "CN=N": "[#6;X3;N][#7;X2]",
    "CN=O": "[#6;X3;N][#8;X2]",
    "C=NS": "[#6;X2;N]=[#16;X2]",
    "CO=O": "[#6;X2;O]=[#8;X2]",
    "C=OCl": "[#6;X2;O]=[#17;X2]",
    "C=OBr": "[#6;X2;O]=[#35;X2]",
    "=CF2": "[#6;X2;F]=[#6;X2;F]",
    "=CFCl": "[#6;X2;F]=[#6;X2;Cl]",
    "=CFBr": "[#6;X2;F]=[#6;X2;Br]",
    "=CCl2": "[#6;X2;Cl]=[#6;X2;Cl]",
    "=CBr2": "[#6;X2;Br]=[#6;X2;Br]",
    "N2=N": "[#7;X2;N]=[#7;X2]",
    "N2=O": "[#7;X2;N]=[#8;X2]",
    "N=NS": "[#7;X2;N]=[#16;X2]",
    "N2=S": "[#7;X2;N]=[#16;X2]",
    "NO=O": "[#7;X2;O]=[#8;X2]",
    "N=OS": "[#7;X2;O]=[#16;X2]",
    "=NOS": "[#7;X2;O]=[#16;X2]",
    "NS=S": "[#7;X2;S]=[#16;X2]",
    "O2=O": "[#8;X2;O]=[#8;X2]",
    "H:C2": "[#6;X3;H]:[#6;X4]",
    "H:C:N": "[#6;X3;H]:[#6;X3]:[#7;X4]",
    "H:N2": "[#6;X3;H]:[#7;X2]",
    ":C3": "[#6;X4]:[#6;X4;C3]",
    "C:C2": "[#6;X4;C2]:[#6;X4]",
    "C:C:N": "[#6;X4;C]:[#6;X4]:[#7;X4]",
